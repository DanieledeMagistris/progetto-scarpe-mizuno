# %%
import pandas as pd

# %%
# Leggi i due file CSV
df = pd.read_csv("Scarpe_Sportive_Splittato_tutto.csv")
dfd = pd.read_csv("Scarpe_Sportive.csv")

# %%
df
# Out:
#              categoria  taglia genere         marca  \
# 0      Scarpe Sportive    35.5   uomo          PUMA
# 1      Scarpe Sportive    35.5   uomo          PUMA
# 2      Scarpe Sportive    35.5   uomo          PUMA
# 3      Scarpe Sportive    35.5   uomo          PUMA
# 4      Scarpe Sportive    35.5   uomo          PUMA
# ...                ...     ...    ...           ...
# 14896  Scarpe Sportive    47.0  donna  UNDER ARMOUR
# 14897  Scarpe Sportive    48.0  donna          PUMA
# 14898  Scarpe Sportive    48.0  donna          PUMA
# 14899  Scarpe Sportive    48.0  donna          PUMA
# 14900  Scarpe Sportive    48.5  donna  UNDER ARMOUR
#
#                                            nome_prodotto  prezzo_effettivo  \
# 0      MORPHIC - Scarpe da corsa su strada - white-wa...             47.95
# 1      MORPHIC - Scarpe da corsa su strada - white-wa...             47.95
# 2      MORPHIC - Scarpe da corsa su strada - white-wa...             47.95
# ...

# %%
# trasformiamo le collone genere e modello in minuscolli
df['genere'] = df['genere'].str.lower()
df['modello'] = df['modello'].str.lower()

# %%
df['modello'].value_counts()
# Out:
# modello
# unknown                          366
# caven 2.0 unisex                 337
# softride enzo 5                  191
# gel kayano 31                    187
# 480 unisex                       183
#                                 ...
# future 7 match laceless fg/ag      1
# ultra match+ ll fg/ag              1
# future 7 match it                  1
# solarstrike ii                     1
# ultra ultimate mxsg                1
# Name: count, Length: 616, dtype: int64

# %%
# trasformiamo dentro la collona marca 'PUMA GOLF' in 'PUMA'
df['marca'] = df['marca'].str.replace('GOLF', '')

# %%
df['marca'].value_counts()
# Out:
# marca
# PUMA            5422
# ASICS           3381
# UNDER ARMOUR    2295
# NEW BALANCE     1947
# MIZUNO          1089
# JOMA             456
# PUMA             251
# DIADORA           60
# Name: count, dtype: int64

# %%
#rimuovere i spazi iniziali e finali
df['marca'] = df['marca'].str.strip()

# %%
dfd
# Out:
#              categoria  taglia genere         marca  \
# 0      Scarpe Sportive    35.5   uomo          PUMA
# 1      Scarpe Sportive    35.5   uomo          PUMA
# 2      Scarpe Sportive    35.5   uomo          PUMA
# 3      Scarpe Sportive    35.5   uomo  UNDER ARMOUR
# 4      Scarpe Sportive    35.5   uomo          PUMA
# ...                ...     ...    ...           ...
# 15284  Scarpe Sportive    47.0  donna  UNDER ARMOUR
# 15285  Scarpe Sportive    48.0  donna          PUMA
# 15286  Scarpe Sportive    48.0  donna          PUMA
# 15287  Scarpe Sportive    48.0  donna          PUMA
# 15288  Scarpe Sportive    48.5  donna  UNDER ARMOUR
#
#                                            nome_prodotto  prezzo_effettivo  \
# 0      MORPHIC - Scarpe da corsa su strada - white-wa...             47.95
# 1      PROSPECT UNISEX - Scarpe da allenamento - blac...             48.95
# 2      PWR HYBRID TR UNISEX - Scarpe da allenamento -...             63.95
# ...

# %%
# trasformiamo le collone genere e modello in minuscolli
dfd['genere'] = dfd['genere'].str.lower()
dfd['modello'] = dfd['modello'].str.lower()

# %%
#trasformiamo dentro la collona marca 'PUMA GOLF' in 'PUMA'
dfd['marca'] = dfd['marca'].str.replace('GOLF', '')

# %%
#rimuovere i spazi iniziali e finali
dfd['marca'] = dfd['marca'].str.strip()

# %%
dfd['marca'].value_counts()
# Out:
# marca
# PUMA            5252
# ASICS           3608
# NEW BALANCE     2405
# UNDER ARMOUR    2385
# MIZUNO          1107
# JOMA             471
# DIADORA           61
# Name: count, dtype: int64

# %%
# trasformiamo tutte le righe dalla collona 'sport' in minuscolo
df.loc[:,'sport'] = df['sport'].str.lower()

# %%
# trasformiamo tutte le righe dalla collona 'sport' in minuscolo
dfd.loc[:,'sport'] = dfd['sport'].str.lower()

# %%
df['sport'].value_counts()
# Out:
# sport
# scarpe da corsa su strada                  4680
# scarpe da allenamento                      1902
# scarpe da calcetto con tacchetti           1786
# scarpe da basket                           1252
# scarpe da trail running                    1180
# scarpe da pallavolo                         703
# sneakers basse                              672
# scarpe da pallamano                         516
# da tennis per terra battuta                 415
# scarpe da tennis per tutte le superfici     373
# scarpe da golf                              277
# scarpe da calcetto                          274
# scarpe da calcio con tacchetti              227
# scarpe da camminata                         209
# scarpe da padel                             199
# ciabatte da mare                            142
# scarpa da hiking                             38
# scarpa da rugby                              30
# scarponi da montagna                         19
# ...

# %%
dfd['sport'].value_counts()
# Out:
# sport
# scarpe da corsa su strada                  4714
# scarpe da allenamento                      1863
# scarpe da calcetto con tacchetti           1686
# scarpe da basket                           1312
# scarpe da trail running                    1232
# sneakers basse                             1018
# scarpe da pallavolo                         737
# scarpe da pallamano                         550
# da tennis per terra battuta                 439
# scarpe da tennis per tutte le superfici     398
# scarpe da golf                              257
# scarpe da calcetto                          242
# scarpe da calcio con tacchetti              232
# scarpe da padel                             217
# scarpe da camminata                         186
# ciabatte da mare                            109
# scarpa da hiking                             39
# scarpa da rugby                              32
# scarponi da montagna                         19
# ...

# %%
#eliminiamo tutte le righe dove sport contiene 'sneakers basse'
df = df[~df['sport'].str.contains('sneakers basse', case=False, na=False)]
df['sport'].value_counts()
# Out:
# sport
# scarpe da corsa su strada                  4680
# scarpe da allenamento                      1902
# scarpe da calcetto con tacchetti           1786
# scarpe da basket                           1252
# scarpe da trail running                    1180
# scarpe da pallavolo                         703
# scarpe da pallamano                         516
# da tennis per terra battuta                 415
# scarpe da tennis per tutte le superfici     373
# scarpe da golf                              277
# scarpe da calcetto                          274
# scarpe da calcio con tacchetti              227
# scarpe da camminata                         209
# scarpe da padel                             199
# ciabatte da mare                            142
# scarpa da hiking                             38
# scarpa da rugby                              30
# scarponi da montagna                         19
# stivali da neve                               7
# Name: count, dtype: int64

# %%
#eliminiamo tutte le righe dove sport contiene 'sneakers basse'
dfd = dfd[~dfd['sport'].str.contains('sneakers basse', case=False, na=False)]
dfd['sport'].value_counts()
# Out:
# sport
# scarpe da corsa su strada                  4714
# scarpe da allenamento                      1863
# scarpe da calcetto con tacchetti           1686
# scarpe da basket                           1312
# scarpe da trail running                    1232
# scarpe da pallavolo                         737
# scarpe da pallamano                         550
# da tennis per terra battuta                 439
# scarpe da tennis per tutte le superfici     398
# scarpe da golf                              257
# scarpe da calcetto                          242
# scarpe da calcio con tacchetti              232
# scarpe da padel                             217
# scarpe da camminata                         186
# ciabatte da mare                            109
# scarpa da hiking                             39
# scarpa da rugby                              32
# scarponi da montagna                         19
# stivali da neve                               7
# Name: count, dtype: int64

# %%
# Salva il risultato in un nuovo file CSV
df.to_csv("Splittato_tutto.csv", index=False)
dfd.to_csv("Colori_aggregati.csv", index=False)

# Stampa una conferma
print("File unito e salvato come 'Scarpe_Sportive_Splittato_tutto.csv'")
# Out:
# File unito e salvato come 'Scarpe_Sportive_Splittato_tutto.csv'

# %%
df = pd.read_csv("Splittato_tutto.csv", encoding='utf-8')

# %%
df
# Out:
#              categoria  taglia genere         marca  \
# 0      Scarpe Sportive    35.5   uomo          PUMA
# 1      Scarpe Sportive    35.5   uomo          PUMA
# 2      Scarpe Sportive    35.5   uomo          PUMA
# 3      Scarpe Sportive    35.5   uomo          PUMA
# 4      Scarpe Sportive    35.5   uomo          PUMA
# ...                ...     ...    ...           ...
# 14224  Scarpe Sportive    47.0  donna  UNDER ARMOUR
# 14225  Scarpe Sportive    48.0  donna          PUMA
# 14226  Scarpe Sportive    48.0  donna          PUMA
# 14227  Scarpe Sportive    48.0  donna          PUMA
# 14228  Scarpe Sportive    48.5  donna  UNDER ARMOUR
#
#                                            nome_prodotto  prezzo_effettivo  \
# 0      MORPHIC - Scarpe da corsa su strada - white-wa...             47.95
# 1      MORPHIC - Scarpe da corsa su strada - white-wa...             47.95
# 2      MORPHIC - Scarpe da corsa su strada - white-wa...             47.95
# ...

# %%
# Convertiamo 'nome_prodotto' in minuscolo
df['nome_prodotto'] = df['nome_prodotto'].str.lower()

# Verifichiamo se 'nome_prodotto' contiene 'unisex' e aggiorna 'genere'
df.loc[df['nome_prodotto'].str.contains('unisex'), 'genere'] = 'unisex'

# Visualizziamo il DataFrame
display(df)
# Out:
#              categoria  taglia  genere         marca  \
# 0      Scarpe Sportive    35.5    uomo          PUMA
# 1      Scarpe Sportive    35.5    uomo          PUMA
# 2      Scarpe Sportive    35.5    uomo          PUMA
# 3      Scarpe Sportive    35.5  unisex          PUMA
# 4      Scarpe Sportive    35.5  unisex          PUMA
# ...                ...     ...     ...           ...
# 14224  Scarpe Sportive    47.0   donna  UNDER ARMOUR
# 14225  Scarpe Sportive    48.0   donna          PUMA
# 14226  Scarpe Sportive    48.0   donna          PUMA
# 14227  Scarpe Sportive    48.0   donna          PUMA
# 14228  Scarpe Sportive    48.5   donna  UNDER ARMOUR
#
#                                            nome_prodotto  prezzo_effettivo  \
# 0      morphic - scarpe da corsa su strada - white-wa...             47.95
# 1      morphic - scarpe da corsa su strada - white-wa...             47.95
# 2      morphic - scarpe da corsa su strada - white-wa...             47.95
# ...

# %%
# Contiamo le righe che contengono "unisex" nella colonna "genere"
conteggio_unisex = len(df[df['genere'] == 'unisex'])

# Visualizziamo il conteggio
print(f"Ci sono {conteggio_unisex} righe con genere 'unisex'.")
# Out:
# Ci sono 1960 righe con genere 'unisex'.

# %%
# Creamo un nuovo DataFrame senza le righe con "unisex" in "genere"
df_senza_unisex = df[df['genere'] != 'unisex']

# Visualizziamo il DataFrame risultante
print(display(df_senza_unisex))
# Out:
#              categoria  taglia genere         marca  \
# 0      Scarpe Sportive    35.5   uomo          PUMA
# 1      Scarpe Sportive    35.5   uomo          PUMA
# 2      Scarpe Sportive    35.5   uomo          PUMA
# 6      Scarpe Sportive    35.5   uomo  UNDER ARMOUR
# 7      Scarpe Sportive    35.5   uomo          PUMA
# ...                ...     ...    ...           ...
# 14224  Scarpe Sportive    47.0  donna  UNDER ARMOUR
# 14225  Scarpe Sportive    48.0  donna          PUMA
# 14226  Scarpe Sportive    48.0  donna          PUMA
# 14227  Scarpe Sportive    48.0  donna          PUMA
# 14228  Scarpe Sportive    48.5  donna  UNDER ARMOUR
#
#                                            nome_prodotto  prezzo_effettivo  \
# 0      morphic - scarpe da corsa su strada - white-wa...             47.95
# 1      morphic - scarpe da corsa su strada - white-wa...             47.95
# 2      morphic - scarpe da corsa su strada - white-wa...             47.95
# ...

# %%
# Salva il risultato in un nuovo file CSV
df.to_csv("Splittato_tutto.csv", index=False)

# Stampa una conferma
print("File unito e salvato come 'Scarpe_Sportive_Splittato_tutto.csv'")
# Out:
# File unito e salvato come 'Scarpe_Sportive_Splittato_tutto.csv'

# %%
dfd = pd.read_csv("Colori_aggregati.csv", encoding='utf-8')

# %%
dfd
# Out:
#              categoria  taglia genere         marca  \
# 0      Scarpe Sportive    35.5   uomo          PUMA
# 1      Scarpe Sportive    35.5   uomo          PUMA
# 2      Scarpe Sportive    35.5   uomo          PUMA
# 3      Scarpe Sportive    35.5   uomo  UNDER ARMOUR
# 4      Scarpe Sportive    35.5   uomo          PUMA
# ...                ...     ...    ...           ...
# 14266  Scarpe Sportive    47.0  donna  UNDER ARMOUR
# 14267  Scarpe Sportive    48.0  donna          PUMA
# 14268  Scarpe Sportive    48.0  donna          PUMA
# 14269  Scarpe Sportive    48.0  donna          PUMA
# 14270  Scarpe Sportive    48.5  donna  UNDER ARMOUR
#
#                                            nome_prodotto  prezzo_effettivo  \
# 0      MORPHIC - Scarpe da corsa su strada - white-wa...             47.95
# 1      PROSPECT UNISEX - Scarpe da allenamento - blac...             48.95
# 2      PWR HYBRID TR UNISEX - Scarpe da allenamento -...             63.95
# ...

# %%
# Convertiamo 'nome_prodotto' in minuscolo
dfd['nome_prodotto'] = dfd['nome_prodotto'].str.lower()

# Verifichiamo se 'nome_prodotto' contiene 'unisex' e aggiorna 'genere'
dfd.loc[dfd['nome_prodotto'].str.contains('unisex'), 'genere'] = 'unisex'

# Visualizziamo il DataFrame
display(dfd)
# Out:
#              categoria  taglia  genere         marca  \
# 0      Scarpe Sportive    35.5    uomo          PUMA
# 1      Scarpe Sportive    35.5  unisex          PUMA
# 2      Scarpe Sportive    35.5  unisex          PUMA
# 3      Scarpe Sportive    35.5    uomo  UNDER ARMOUR
# 4      Scarpe Sportive    35.5    uomo          PUMA
# ...                ...     ...     ...           ...
# 14266  Scarpe Sportive    47.0   donna  UNDER ARMOUR
# 14267  Scarpe Sportive    48.0   donna          PUMA
# 14268  Scarpe Sportive    48.0   donna          PUMA
# 14269  Scarpe Sportive    48.0   donna          PUMA
# 14270  Scarpe Sportive    48.5   donna  UNDER ARMOUR
#
#                                            nome_prodotto  prezzo_effettivo  \
# 0      morphic - scarpe da corsa su strada - white-wa...             47.95
# 1      prospect unisex - scarpe da allenamento - blac...             48.95
# 2      pwr hybrid tr unisex - scarpe da allenamento -...             63.95
# ...

# %%
# Contiamo le righe che contengono "unisex" nella colonna "genere"
conteggio_unisex = len(dfd[dfd['genere'] == 'unisex'])

# Visualizziamo il conteggio
print(f"Ci sono {conteggio_unisex} righe con genere 'unisex'.")
# Out:
# Ci sono 1955 righe con genere 'unisex'.

# %%
# Creamo un nuovo DataFrame senza le righe con "unisex" in "genere"
df_senza_unisex = df[df['genere'] != 'unisex']

# Visualizziamo il DataFrame risultante
print(display(df_senza_unisex))
# Out:
#              categoria  taglia genere         marca  \
# 0      Scarpe Sportive    35.5   uomo          PUMA
# 1      Scarpe Sportive    35.5   uomo          PUMA
# 2      Scarpe Sportive    35.5   uomo          PUMA
# 6      Scarpe Sportive    35.5   uomo  UNDER ARMOUR
# 7      Scarpe Sportive    35.5   uomo          PUMA
# ...                ...     ...    ...           ...
# 14224  Scarpe Sportive    47.0  donna  UNDER ARMOUR
# 14225  Scarpe Sportive    48.0  donna          PUMA
# 14226  Scarpe Sportive    48.0  donna          PUMA
# 14227  Scarpe Sportive    48.0  donna          PUMA
# 14228  Scarpe Sportive    48.5  donna  UNDER ARMOUR
#
#                                            nome_prodotto  prezzo_effettivo  \
# 0      morphic - scarpe da corsa su strada - white-wa...             47.95
# 1      morphic - scarpe da corsa su strada - white-wa...             47.95
# 2      morphic - scarpe da corsa su strada - white-wa...             47.95
# ...

# %%
# Salva il risultato in un nuovo file CSV
df.to_csv("Colori_aggregati.csv", index=False)

# Stampa una conferma
print("File unito e salvato come 'Scarpe_Sportive_Splittato_tutto.csv'")
# Out:
# File unito e salvato come 'Scarpe_Sportive_Splittato_tutto.csv'
